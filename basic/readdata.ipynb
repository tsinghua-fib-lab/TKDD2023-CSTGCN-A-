# %%
import pickle
import numpy as np
with open("gps_list.pkl","rb") as f:
    gps_l = pickle.load(f)
with open("state_trans.pkl","rb") as f:
    state_tran = pickle.load(f)

# %%
len(gps_l)
# Out:
# 486

# %%
state_tran
# Out:
# {1: [2, 4, 7, 8],
#  2: [1, 7, 8, 48],
#  3: [5, 6, 318],
#  4: [1, 5],
#  5: [3, 4],
#  6: [3, 9, 318, 460],
#  7: [1, 2, 8, 436],
#  8: [1, 2, 7, 436, 462],
#  9: [6, 10, 331],
#  10: [9, 11, 331],
#  11: [10, 12, 69, 333],
#  12: [11, 14],
#  13: [76, 200],
#  14: [12, 105, 226],
#  15: [83, 293, 315, 383],
#  16: [254, 266, 383, 411],
#  17: [84, 217, 373, 411],
#  18: [137, 315, 373, 425],
#  19: [215, 419, 425],
#  20: [80, 146, 216, 232],
#  21: [22, 80, 232, 444],
#  22: [21, 80, 444],
#  23: [99, 102, 438, 474],
#  24: [26, 168, 169, 322],
#  25: [113, 190, 435],
#  26: [24, 118, 167, 322],
#  27: [387],
#  28: [31, 249, 408],
#  29: [31, 245, 246],
#  30: [122, 245, 247, 387],
#  31: [28, 29],
#  32: [253, 256],
#  33: [212],
#  34: [293, 424],
#  35: [212],
#  36: [38, 211, 212, 368],
#  37: [96, 254, 481],
#  38: [36, 123, 126, 127, 128, 129, 211, 287, 303],
#  39: [256],
#  40: [293, 424, 480],
#  41: [42, 54, 278, 431],
#  42: [41, 54, 278, 431],
#  43: [48, 279, 378],
# ...

# %%
len(gps_l)
# Out:
# 486

# %%
data = np.load("data_one_day.npy")[:,:,0]

# %%
data.shape
# Out:
# (288, 486)

# %%
data.mean()
# Out:
# 91.0342

# %%
gps_la = np.array(gps_l)
big, small = gps_la.max(axis=0), gps_la.min(axis=0)

# %%
s = big-small
-s
# Out:
# array([-0.0871988, -0.0714478])

# %%
np.linalg.norm(-s)
# Out:
# 0.11273162309786676

# %%
s
# Out:
# array([0.0871988, 0.0714478])
